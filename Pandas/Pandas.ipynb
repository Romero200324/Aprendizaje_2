# %%
# Creacion de proyecto de PNADAS
import pandas as pd

# %%
df = pd.read_csv("listado_estaciones.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.read_csv("listado_estaciones.csv")
#
# File c:\Users\oro00\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
#                                                                                                                           Fecha_creación  \
# 2020-09-11 21:09:23 1304527483526688775 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             NaN
# 2020-09-11 20:56:44 1304524297331970050 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             NaN
# 2020-09-11 20:11:46 1304512981254971398 RT @Milenio: El director del IMSS encabezó el h... Twitter for iPhone  False NaN             NaN
# 2020-09-11 20:06:41 1304511701908426752 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             NaN
# 2020-09-11 20:04:00 1304511027627864067 El director del IMSS encabezó el homenaje que s... TweetDeck           True  NaN             NaN
#
#                                                                                                                            Id  \
# ...

# %%
df.dtypes
# Out:
# Fecha_creación                 float64
# Id                              object
# Texto                          float64
# Fuente                         float64
# Truncado                       float64
# Respuesta_al_tweet             float64
# Respuesta_al_usuario_id         object
# Respuesta_al_usuario_nombre       bool
# dtype: object

# %%
df.dropna()
df.describe()
df.fillna(2)
# Out:
#                                                                                                                           Fecha_creación  \
# 2020-09-11 21:09:23 1304527483526688775 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             2.0
# 2020-09-11 20:56:44 1304524297331970050 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             2.0
# 2020-09-11 20:11:46 1304512981254971398 RT @Milenio: El director del IMSS encabezó el h... Twitter for iPhone  False NaN             2.0
# 2020-09-11 20:06:41 1304511701908426752 RT @Milenio: El director del IMSS encabezó el h... Twitter for Android False NaN             2.0
# 2020-09-11 20:04:00 1304511027627864067 El director del IMSS encabezó el homenaje que s... TweetDeck           True  NaN             2.0
# ...                                                                                                                                  ...
# ...

# %%
df.iloc[1]
# Out:
# Fecha_creación                   NaN
# Id                               NaN
# Texto                            NaN
# Fuente                           NaN
# Truncado                         NaN
# Respuesta_al_tweet               NaN
# Respuesta_al_usuario_id           es
# Respuesta_al_usuario_nombre    False
# Name: (2020-09-11 20:56:44, 1304524297331970050, RT @Milenio: El director del IMSS encabezó el homenaje que se lleva a cabo todos los días a las 12:00 horas al personal de salud y a víctim…, Twitter for Android, False, nan), dtype: object

# %%
df[df[0]> 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\oro00\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[df[0]> 1]
#
# ...
