# %% [markdown]
# # Sección nueva

# %% [markdown]
# # Implementacion de datos de python en con la libreria de pandas.
#
#
# ### "Una de las implementaciones de datos para realizar el codigo de manera adecuada..."
#
# ![Implementacion de datos](https://aprendeconalf.es/docencia/python/manual/img/pandas-logo.png)

# %%
import pandas as pd

# Lee el archivo .ipynb usando pandas
df = pd.read_json('Ciencia_de_datos.ipynb')

# Accede al contenido del cuaderno (notebook)
contenido = df['Estado_nomina.csv']

# Itera sobre las celdas y procesa el contenido
codigo_python = ''
for celda in contenido:
    if celda['cell_type'] == 'code':
        codigo_python += '\n'.join(celda['source']) + '\n\n'

# Corrige los caracteres especiales y la codificación
# Puedes realizar otras operaciones de limpieza aquí si es necesario

# Guarda el código procesado en un archivo .py
with open('archivo.py', 'w', encoding='utf-8') as f:
    f.write(codigo_python)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b11982ad4a6c> in <cell line: 4>()
#       2
#       3 # Lee el archivo .ipynb usando pandas
# ----> 4 df = pd.read_json('Ciencia_de_datos.ipynb')
#       5
#       6 # Accede al contenido del cuaderno (notebook)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
